# %%
import os
import pandas as pd
import utils.plot_utls as plt_utils

# %%
plt_utils.setup_plots()

# %%
FIGURES_DIRECTORY = f'{os.getcwd()}/../figures/data-analysis'
FIGURES_DIRECTORY_WINE = f'{FIGURES_DIRECTORY}/wine'
FIGURES_DIRECTORY_CARDS = f'{FIGURES_DIRECTORY}/cards'

# %% [markdown]
# # Wine Quality dataset

# %%
wine_df = pd.read_csv('../datasets/wine-quality/wine-quality-all.csv', delimiter=';', encoding='utf-8')

# %%
wine_df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.66         0.00             1.8      0.075
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 13.0                  40.0   0.9978  3.51       0.56
#
#    alcohol  quality color
# 0      9.4        5   red
# 1      9.8        5   red
# ...

# %%
wine_df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    5320.000000       5320.000000  5320.000000     5320.000000
# mean        7.215179          0.344130     0.318494        5.048477
# std         1.319671          0.168248     0.147157        4.500180
# min         3.800000          0.080000     0.000000        0.600000
# 25%         6.400000          0.230000     0.240000        1.800000
# 50%         7.000000          0.300000     0.310000        2.700000
# 75%         7.700000          0.410000     0.400000        7.500000
# max        15.900000          1.580000     1.660000       65.800000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  5320.000000          5320.000000           5320.000000  5320.000000
# mean      0.056690            30.036654            114.109023     0.994535
# std       0.036863            17.805045             56.774223     0.002966
# ...

# %%
wine_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5320 entries, 0 to 5319
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         5320 non-null   float64
#  1   volatile acidity      5320 non-null   float64
#  2   citric acid           5320 non-null   float64
#  3   residual sugar        5320 non-null   float64
#  4   chlorides             5320 non-null   float64
#  5   free sulfur dioxide   5320 non-null   float64
#  6   total sulfur dioxide  5320 non-null   float64
#  7   density               5320 non-null   float64
#  8   pH                    5320 non-null   float64
#  9   sulphates             5320 non-null   float64
#  10  alcohol               5320 non-null   float64
#  11  quality               5320 non-null   int64
#  12  color                 5320 non-null   object
# dtypes: float64(11), int64(1), object(1)
# memory usage: 540.4+ KB

# %%
plt_utils.label_distribution_chart(
    wine_df,
    'quality',
    'Label Distribution',
    save_path=f"{FIGURES_DIRECTORY_WINE}/labels-distribution-all.png"
)

# %%
plt_utils.label_distribution_chart(
    wine_df[wine_df['color'] == 'white'],
    'quality',
    'Label Distribution (white wine)',
    save_path=f"{FIGURES_DIRECTORY_WINE}/labels-distribution-white.png"
)

# %%
plt_utils.label_distribution_chart(
    wine_df[wine_df['color'] == 'red'],
    'quality',
    'Label Distribution (red wine)',
    save_path=f"{FIGURES_DIRECTORY_WINE}/labels-distribution-red.png")

# %%
plt_utils.label_distribution_chart(
    wine_df,
    ['quality', 'color'],
    'Label Distribution (with split by color)',
    save_path=f"{FIGURES_DIRECTORY_WINE}/labels-distribution-split-colors.png")

# %% [markdown]
# # Credit Card Fraud dataset

# %%
credit_df = pd.read_csv('../datasets/credit-card/credit-card-all.csv', delimiter=';', encoding='utf-8')
credit_df_small = pd.read_csv('../datasets/credit-card/credit-card-small.csv', delimiter=';', encoding='utf-8')

# %%
credit_df.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  1.168375e-15  3.416908e-16 -1.379537e-15  2.074095e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   9.604066e-16  1.487313e-15 -5.556467e-16  1.213481e-16 -2.406331e-15
# ...

# %%
credit_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
credit_df_small.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count   71571.000000  71571.000000  71571.000000  71571.000000  71571.000000
# mean    94514.230051     -0.022728      0.022065     -0.032756      0.028861
# std     47489.951068      2.034850      1.695688      1.676636      1.464519
# min         1.000000    -37.558067    -50.383269    -32.454198     -5.263068
# 25%     54037.500000     -0.927345     -0.592162     -0.903419     -0.843677
# 50%     84509.000000      0.007712      0.073650      0.173371     -0.002559
# 75%    139119.500000      1.314704      0.810341      1.027213      0.764997
# max    172786.000000      2.454930     22.057729      4.226108     12.132323
#
#                  V5            V6            V7            V8            V9  \
# count  71571.000000  71571.000000  71571.000000  71571.000000  71571.000000
# mean      -0.017869     -0.004728     -0.027596      0.007005     -0.017429
# ...

# %%
credit_df_small.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 71571 entries, 0 to 71570
# Data columns (total 31 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Time    71571 non-null  float64
#  1   V1      71571 non-null  float64
#  2   V2      71571 non-null  float64
#  3   V3      71571 non-null  float64
#  4   V4      71571 non-null  float64
#  5   V5      71571 non-null  float64
#  6   V6      71571 non-null  float64
#  7   V7      71571 non-null  float64
#  8   V8      71571 non-null  float64
#  9   V9      71571 non-null  float64
#  10  V10     71571 non-null  float64
#  11  V11     71571 non-null  float64
#  12  V12     71571 non-null  float64
#  13  V13     71571 non-null  float64
#  14  V14     71571 non-null  float64
#  15  V15     71571 non-null  float64
#  16  V16     71571 non-null  float64
#  17  V17     71571 non-null  float64
#  18  V18     71571 non-null  float64
#  19  V19     71571 non-null  float64
# ...

# %%
plt_utils.label_distribution_chart(
    credit_df,
    'Class',
    'Label Distribution',
    save_path=f"{FIGURES_DIRECTORY_CARDS}/labels-distribution-all.png"
)

# %%
plt_utils.label_distribution_chart(
    credit_df_small,
    'Class',
    'Label Distribution',
    save_path=f"{FIGURES_DIRECTORY_CARDS}/labels-distribution-small.png"
)

# %%
import importlib
import ChartProducer as chp
from math import comb
importlib.reload(chp)
# Out:
# <module 'ChartProducer' from '/Users/pavponn/gatech/machine-learning/assignment-2/ChartProducer.py'>

# %%
problem_sizes = [10, 25, 50]
producer = chp.ChartProducer('queens', problem_sizes, max_fitness=[comb(sz, 2) for sz in problem_sizes], maximise=False)
# Out:
# All datasets loaded!

# %%
producer.plot_all_series_for_all()
producer.plot_all_series_for_all(curve='Time')
producer.plot_best_series_for_all_sizes()
producer.plot_best_series_for_all_sizes(curve='Time')
producer.plot_best_series_for_all_sizes(curve='FEvals')
producer.plog_best_series_for_all_algos_one_plot(curve='Fitness')
producer.plog_best_series_for_all_algos_one_plot(curve='Time')
producer.plog_best_series_for_all_algos_one_plot(curve='FEvals')
# Out:
# /Users/pavponn/gatech/machine-learning/assignment-2/ChartProducer.py:158: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df['Algorithm'] = algo.upper()
# /Users/pavponn/gatech/machine-learning/assignment-2/ChartProducer.py:159: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df['Problem Size'] = size
# /Users/pavponn/gatech/machine-learning/assignment-2/ChartProducer.py:158: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
for problem_size in problem_sizes:
    print(producer._get_best_parameters_by_fitness(problem_size))
# Out:
# {'10-ga': [0.6], '10-mimic': [0.5], '10-rhc': [], '10-sa': [0.1]}
# {'25-ga': [0.8], '25-mimic': [0.7], '25-rhc': [], '25-sa': [0.1]}
# {'50-ga': [0.6], '50-mimic': [0.7], '50-rhc': [], '50-sa': [0.5]}
